# %% [markdown]
# # Interface para Geração de Personas Sintéticas (HDT 7S)
#
# Execute a célula abaixo para abrir a interface Gradio.

# %%
from utils import UIUtils

ui = UIUtils()
ui.launch(inline=True)
# ui.launch(inbrowser=True, debug=True, share=False)
